# %% [markdown]
# ## Testing

# %%
import sys
MODEL = "mistralai/Mistral-7B-v0.1"
DEVICE = "cuda:0"
LIMIT = 300

BASE_OUT = f"outputs/mistral7b_hellaswag_limit{LIMIT}_baseline.json"

# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained={MODEL},load_in_8bit=True \
  --tasks hellaswag \
  --device {DEVICE} \
  --limit {LIMIT} \
  --output_path {BASE_OUT}
# Out:
# 2026-02-26:11:04:24 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-26:11:04:32 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-02-26:11:04:32 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-26:11:04:32 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'mistralai/Mistral-7B-v0.1', 'load_in_8bit': True}
# 2026-02-26:11:04:33 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:51<00:00, 25.80s/it]
# Not restoring or scaling GO...
# ...

# %%
import sys

MODEL = "mistralai/Mistral-7B-v0.1"
DEVICE = "cuda:0"

p = 5e-5
LIMIT = 50   

out = f"outputs/test_search_p{p}.json"
outlier = f"search_percentage_tensor_percentage_{p}"

# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained={MODEL},load_in_8bit=True,outlier_method={outlier},layers=0-31,outlier_weight_type=all \
  --tasks hellaswag \
  --device {DEVICE} \
  --limit {LIMIT} \
  --output_path {out}
# Out:
# 2026-02-26:12:05:00 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-26:12:05:06 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-02-26:12:05:06 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-26:12:05:06 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'mistralai/Mistral-7B-v0.1', 'load_in_8bit': True, 'outlier_method': 'search_percentage_tensor_percentage_5e-05', 'layers': '0-31', 'outlier_weight_type': 'all'}
# 2026-02-26:12:05:06 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# ...

# %%
import sys

# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained=mistralai/Mistral-7B-v0.1,load_in_8bit=True,outlier_method=search_percentage_tensor_percentage_5e-05,layers=0-31 \
  --tasks hellaswag \
  --device cuda:0 \
  --limit 20 \
  --output_path outputs/restart_smoketest.json
# Out:
# 2026-02-26:13:57:30 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-26:13:57:40 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-02-26:13:57:40 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-26:13:57:40 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'mistralai/Mistral-7B-v0.1', 'load_in_8bit': True, 'outlier_method': 'search_percentage_tensor_percentage_5e-05', 'layers': '0-31'}
# 2026-02-26:13:57:40 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:47<00:00, 23.56s/it]
# ...

# %% [markdown]
# ## Superweight ablation

# %%
ABL_OUT = f"outputs/mistral7b_hellaswag_limit{LIMIT}_ablateGO.json"

# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained={MODEL},load_in_8bit=True,outlier_method=manual_scaling_SO_0.0 \
  --tasks hellaswag \
  --device {DEVICE} \
  --limit {LIMIT} \
  --output_path {ABL_OUT}
# Out:
# 2026-02-26:14:42:07 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-26:14:42:12 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-02-26:14:42:12 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-26:14:42:12 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'mistralai/Mistral-7B-v0.1', 'load_in_8bit': True, 'outlier_method': 'manual_scaling_SO_0.0'}
# 2026-02-26:14:42:12 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:48<00:00, 24.13s/it]
# manual scaling SO
# ...

# %% [markdown]
# ### Baseline

# %%
# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained={MODEL},load_in_8bit=True \
  --tasks hellaswag \
  --device {DEVICE} \
  --limit 50 \
  --output_path outputs/mistral7b_hellaswag_limit50_baseline_8bit.json
# Out:
# 2026-02-26:14:45:58 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-26:14:46:04 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-02-26:14:46:04 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-26:14:46:04 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'mistralai/Mistral-7B-v0.1', 'load_in_8bit': True}
# 2026-02-26:14:46:04 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:47<00:00, 23.81s/it]
# Not restoring or scaling GO...
# ...

# %% [markdown]
# ## Random ablation

# %%
# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained=mistralai/Mistral-7B-v0.1,load_in_8bit=True,outlier_method=random_ablate_1234 \
  --tasks hellaswag \
  --device cuda:0 \
  --limit 50 \
  --output_path outputs/mistral7b_hellaswag_limit50_random_1234.json
# Out:
# 2026-02-26:15:03:07 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-26:15:03:13 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-02-26:15:03:13 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-26:15:03:13 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'mistralai/Mistral-7B-v0.1', 'load_in_8bit': True, 'outlier_method': 'random_ablate_1234'}
# 2026-02-26:15:03:13 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:46<00:00, 23.26s/it]
# Random single weight ablation
# ...
