# %% [markdown]
# ## Superweight ablation

# %%
import sys

# %%
MODEL = "allenai/OLMo-1B-0724-hf"
DEVICE = "cuda:0"
LIMIT = 300

# %%
BASE_OUT = f"outputs/olmo1b_hellaswag_limit{LIMIT}_baseline_8bit.json"
ABL_OUT  = f"outputs/olmo1b_hellaswag_limit{LIMIT}_SW_ablation_4x.json"
RAND_OUT = f"outputs/olmo1b_hellaswag_limit{LIMIT}_random_1234.json"

# %%
# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained={MODEL},load_in_8bit=True,outlier_method=manual_scaling_SO_0.0 \
  --tasks hellaswag \
  --device {DEVICE} \
  --limit {LIMIT} \
  --output_path {ABL_OUT}
# Out:
# 2026-03-25:14:41:04 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-25:14:41:13 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-03-25:14:41:13 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-03-25:14:41:13 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'allenai/OLMo-1B-0724-hf', 'load_in_8bit': True, 'outlier_method': 'manual_scaling_SO_0.0'}
# 2026-03-25:14:41:13 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:20<00:00, 10.32s/it]
# manual scaling SO
# Original SO: {(1, 1764, 1710): 127, (2, 1764, 8041): -127}
# Layer 1, Index [1764, 1710], Old value: 127, New value: 0.0
# Layer 2, Index [1764, 8041], Old value: -127, New value: -0.0
# Not restoring or scaling GO...
# 2026-03-25:14:41:40 INFO     [evaluator_utils:446] Selected tasks:
# 2026-03-25:14:41:40 INFO     [evaluator_utils:480] Task: hellaswag (hellaswag/hellaswag.yaml)
# 2026-03-25:14:41:40 INFO     [api.task:312] Building contexts for hellaswag on rank 0...
# 100%|███████████████████████████████████████| 300/300 [00:00<00:00, 2528.54it/s]
# 2026-03-25:14:41:40 INFO     [evaluator:575] Running loglikelihood requests
# Running loglikelihood requests: 100%|███████| 1200/1200 [01:17<00:00, 15.58it/s]
# 2026-03-25:14:42:59 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf-outlier ({'pretrained': 'allenai/OLMo-1B-0724-hf', 'load_in_8bit': True, 'outlier_method': 'manual_scaling_SO_0.0'}), gen_kwargs: ({}), limit: 300.0, num_fewshot: None, batch_size: 1
# |  Tasks  |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------|------:|------|-----:|--------|---|-----:|---|-----:|
# |hellaswag|      1|none  |     0|acc     |↑  |0.2867|±  |0.0262|
# |         |       |none  |     0|acc_norm|↑  |0.3300|±  |0.0272|

# %% [markdown]
# ## Baseline

# %%
# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained={MODEL},load_in_8bit=True \
  --tasks hellaswag \
  --device {DEVICE} \
  --limit {LIMIT} \
  --output_path {BASE_OUT}
# Out:
# 2026-03-25:14:43:05 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-25:14:43:11 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-03-25:14:43:11 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-03-25:14:43:11 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'allenai/OLMo-1B-0724-hf', 'load_in_8bit': True}
# 2026-03-25:14:43:11 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:19<00:00,  9.58s/it]
# Not restoring or scaling GO...
# 2026-03-25:14:43:36 INFO     [evaluator_utils:446] Selected tasks:
# 2026-03-25:14:43:36 INFO     [evaluator_utils:480] Task: hellaswag (hellaswag/hellaswag.yaml)
# 2026-03-25:14:43:36 INFO     [api.task:312] Building contexts for hellaswag on rank 0...
# 100%|███████████████████████████████████████| 300/300 [00:00<00:00, 2470.85it/s]
# 2026-03-25:14:43:36 INFO     [evaluator:575] Running loglikelihood requests
# Running loglikelihood requests: 100%|███████| 1200/1200 [01:16<00:00, 15.74it/s]
# 2026-03-25:14:44:54 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf-outlier ({'pretrained': 'allenai/OLMo-1B-0724-hf', 'load_in_8bit': True}), gen_kwargs: ({}), limit: 300.0, num_fewshot: None, batch_size: 1
# |  Tasks  |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------|------:|------|-----:|--------|---|-----:|---|-----:|
# |hellaswag|      1|none  |     0|acc     |↑  |0.4467|±  |0.0288|
# |         |       |none  |     0|acc_norm|↑  |0.5500|±  |0.0288|

# %% [markdown]
# ## Random Ablation

# %%
# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained={MODEL},load_in_8bit=True,outlier_method=random_ablate_1234 \
  --tasks hellaswag \
  --device {DEVICE} \
  --limit {LIMIT} \
  --output_path {RAND_OUT}
# Out:
# 2026-03-25:14:57:17 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-25:14:57:23 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-03-25:14:57:23 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-03-25:14:57:23 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'allenai/OLMo-1B-0724-hf', 'load_in_8bit': True, 'outlier_method': 'random_ablate_1234'}
# 2026-03-25:14:57:23 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:19<00:00,  9.66s/it]
# Random ablation: 2 random weights (matched to SW coordinates/layers)
# [RANDOM ABLATION] layer=1 idx=(815,723) old=-26 new=0.0
# [RANDOM ABLATION] layer=1 idx=(1318,7221) old=22 new=0.0
# Not restoring or scaling GO...
# 2026-03-25:14:57:48 INFO     [evaluator_utils:446] Selected tasks:
# 2026-03-25:14:57:48 INFO     [evaluator_utils:480] Task: hellaswag (hellaswag/hellaswag.yaml)
# 2026-03-25:14:57:48 INFO     [api.task:312] Building contexts for hellaswag on rank 0...
# 100%|███████████████████████████████████████| 300/300 [00:00<00:00, 2174.54it/s]
# 2026-03-25:14:57:48 INFO     [evaluator:575] Running loglikelihood requests
# Running loglikelihood requests: 100%|███████| 1200/1200 [01:20<00:00, 15.00it/s]
# 2026-03-25:14:59:10 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf-outlier ({'pretrained': 'allenai/OLMo-1B-0724-hf', 'load_in_8bit': True, 'outlier_method': 'random_ablate_1234'}), gen_kwargs: ({}), limit: 300.0, num_fewshot: None, batch_size: 1
# |  Tasks  |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------|------:|------|-----:|--------|---|-----:|---|-----:|
# |hellaswag|      1|none  |     0|acc     |↑  |0.4367|±  |0.0287|
# |         |       |none  |     0|acc_norm|↑  |0.5433|±  |0.0288|

# %% [markdown]
# ## Mix Ablate 1 SW + 1 random

# %%
# !{sys.executable} evaluate.py \
  --model hf-outlier \
  --model_args pretrained={MODEL},load_in_8bit=True,outlier_method=mix_ablate_1_1234 \
  --tasks hellaswag \
  --device {DEVICE} \
  --limit {LIMIT} \
  --output_path outputs/olmo7b_hellaswag_limit{LIMIT}_mix1.json
# Out:
# 2026-03-25:14:59:23 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-03-25:14:59:28 INFO     [_cli.run:378] Selected Tasks: ['hellaswag']
# 2026-03-25:14:59:28 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-03-25:14:59:28 INFO     [evaluator:238] Initializing hf-outlier model, with arguments: {'pretrained': 'allenai/OLMo-1B-0724-hf', 'load_in_8bit': True, 'outlier_method': 'mix_ablate_1_1234'}
# 2026-03-25:14:59:28 INFO     [models.huggingface:161] Using device 'cuda:0'
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:19<00:00,  9.70s/it]
# Mix ablation: replace superweights with random weights step-by-step
# [MIX ABLATION] kind=SW layer=1 idx=(1764,1710) old=127 new=0.0
# [MIX ABLATION] kind=RND layer=1 idx=(815,723) old=-26 new=0.0
# Not restoring or scaling GO...
# 2026-03-25:14:59:54 INFO     [evaluator_utils:446] Selected tasks:
# 2026-03-25:14:59:54 INFO     [evaluator_utils:480] Task: hellaswag (hellaswag/hellaswag.yaml)
# 2026-03-25:14:59:54 INFO     [api.task:312] Building contexts for hellaswag on rank 0...
# 100%|███████████████████████████████████████| 300/300 [00:00<00:00, 2386.09it/s]
# 2026-03-25:14:59:54 INFO     [evaluator:575] Running loglikelihood requests
# Running loglikelihood requests: 100%|███████| 1200/1200 [01:17<00:00, 15.45it/s]
# 2026-03-25:15:01:14 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# hf-outlier ({'pretrained': 'allenai/OLMo-1B-0724-hf', 'load_in_8bit': True, 'outlier_method': 'mix_ablate_1_1234'}), gen_kwargs: ({}), limit: 300.0, num_fewshot: None, batch_size: 1
# |  Tasks  |Version|Filter|n-shot| Metric |   |Value |   |Stderr|
# |---------|------:|------|-----:|--------|---|-----:|---|-----:|
# |hellaswag|      1|none  |     0|acc     |↑  |0.3167|±  |0.0269|
# |         |       |none  |     0|acc_norm|↑  |0.3333|±  |0.0273|
